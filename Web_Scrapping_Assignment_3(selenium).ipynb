# %%
#importing all the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import ElementClickInterceptedException

# %% [markdown]
# # Q1: Write a python program which searches all the product under a particular product vertical from www.amazon.in. The product verticals to be searched will be taken as input from user. For e.g. If user input is 'guitar'. Then search for guitars.

# %%
class AmazonPro(object):                      #initiating class
    
    def __init__(self,items):                 #defining class object
        self.amazon_url="https://www.amazon.in/"   #passing url
        self.items = items                         #defining variables
        self.profile=webdriver.Chrome(r"C:\Users\Win 10\Downloads\chromedriver_win32\chromedriver")
        self.driver=webdriver.Chrome("chromedriver")            #getting webdriver 
        self.driver.get(self.amazon_url)  
        
        
    def search_items(self):                          #defining new function with class object
        urls=[]
        prices=[]                                    #empty list to store data
        names=[]
        for item in self.items:                       #using for loop
            print(f"Searching for {items}:")
            
            self.driver.get(self.amazon_url)
            search_field=self.driver.find_element_by_id("twotabsearchtextbox")    #fetching search tag using id name
            search_field.send_keys(item)                                      #sending keys into search field
            
            time.sleep(2)
            
            search_button=self.driver.find_element_by_id("nav-search-submit-button")  #fetching search tag using id name
            search_button.click()                                      #submitting search_button
            
            time.sleep(1)

items=[input("Enter item")]                                 # making search_field as user input
try:
    amazon_pro=AmazonPro(items)
    amazon_pro.search_items()                               #using try and except method
    print("Item searched")                                 
except:
    print("No Such item exist")
# Out:
# Enter itemSneakers
# Searching for ['Sneakers']:
# Item searched

# %% [markdown]
# # Q2:In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a dataframe and csv. In case if any product has less than 3 pages in search results then scrape all the products available under that product vertical. Details to be scraped are: "Brand Name", "Name of the Product", "Rating", "No. of Ratings", "Price", "Return/Exchange", "Expected Delivery", "Availability", "Other Details" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by "-".

# %%
brand_tags=[]    #empty list
for bran in range(10):
    try:
        for brand in driver.find_elements_by_xpath("//h5[@class='s-line-clamp-1']/span"): #fetching brand tag using xpath
            brand_tags.append(brand.text)
    except:
        brand_tags.append("-")
print(brand_tags)
# Out:
# ['Skechers', 'Walkway', "Neeman's", "Neeman's", 'Red Tape', 'Puma', 'Converse', 'Bond Street by (Red Tape)', 'Kraasa', 'Allen Solly', 'Reebok Classics', 'PARAGON', 'Puma', 'Bacca Bucci', 'Red Tape', 'Red Tape', 'Amazon Brand - Symbol', 'Amazon Brand - House & Shields', 'Fashion Faster', 'Puma', 'FURO by Redchief', 'PAZZION', 'Pro', 'PAZZION', 'Centrino', 'Sparx', 'Reebok Classics', 'Sparx', 'Red Tape', 'Sparx', 'Centrino', 'kardam&sons', 'Centrino', 'White Walkers', 'Lee Cooper', 'Sparx', 'Red Tape', 'Fila', 'Red Tape', 'Red Tape', "Levi's", 'crocs', 'Centrino', 'Puma', 'Red Tape', 'Puma', 'Sparx', 'Amazon Brand - Symbol', 'Bond Street by (Red Tape)', 'Generic', 'Franco Leone', 'Amazon Brand - Symbol', 'Red Tape', 'Puma', 'Stinson', 'Centrino', 'Skechers', 'PAZZION', 'Generic', 'Clarks', 'Skechers', 'Walkway', "Neeman's", "Neeman's", 'Red Tape', 'Puma', 'Converse', 'Bond Street by (Red Tape)', 'Kraasa', 'Allen Solly', 'Reebok Classics', 'PARAGON', 'Puma', 'Bacca Bucci', 'Red Tape', '
# ...

# %%
prod_tags=[]#empty list
for pro in range(10):
    try:
        for elem1 in driver.find_elements_by_xpath("//span[@class='a-size-base-plus a-color-base a-text-normal']"): #fetching product name tag using xpath
            prod_tags.append(elem1.text)
    except:
        prod_tags.append("-")
print(prod_tags)
# Out:
# ["Men's Benago-Extended Sneaker", "Men's 252-9880 Sneakers", "Women's Wool Joggers Shoes (Coral Red)", 'ReLive Knit Casual Slip On Shoes for Men', "Men's Sneaker", 'Unisex-Adult Backcourt Mid Boot', "Men's Sneakers", "Men's Sneakers", 'Young Choice Sneakers for Men', "Men's Seasonal Fashion Sneakers", "Men's Reebok Royal Complete CLN BSC Sneaker", "Men's Casual Shoes", "Men's Escaper Mesh Sneaker", 'Urbane Men Fashion Hi Top Sneakers/Street Wear with Dual Air Cushion Rubber Outsole for Swag, Travel, Parties, Dancing, Dating, Streets & Fun', "Men's Rte1726 Sneakers", "Men's Rte3161 Sneaker", "Men's Canvas Sneakers", 'Men Canvas Sneakers', "Sneakers Running Walking Shoes for Men's", "Men's One8 V2 Idp Sneakers", "FURO Men's Grey Sneaker", 'Slip-on Platform Leather Sneakers', "by Khadim's Men's Dress Sneaker", 'Black Vintage Bow Sneakers', 'Men Sneakers', "Men's Sc0360g Canvas Sneakers", "Men's Reebok Clubpro Sneaker", "Men's Sneakers", "Men's Rte3107 Sneaker", "Women's Sx0146l Walking 
# ...

# %%
urls=[]    #fetching the urls
for i in driver.find_elements_by_xpath("//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']//a"):
    urls.append(i.get_attribute("href"))
urls
# Out:
# ['https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_next_aps_sr_pg5_1?ie=UTF8&adId=A02711731MXW448ZP77I3&url=%2FSkechers-BENAGO-Extended-Black-Sneaker-11-210162-BBK%2Fdp%2FB08651GVL6%2Fref%3Dsr_1_193_sspa%3Fdchild%3D1%26keywords%3DSneakers%26qid%3D1632468513%26sr%3D8-193-spons%26psc%3D1&qualifier=1632468513&id=7798684811302917&widgetName=sp_atf_next',
#  'https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_next_aps_sr_pg5_1?ie=UTF8&adId=A06755632ZCR736VLOPOY&url=%2FWalkway-Black-Sneakers-10-252-9880%2Fdp%2FB08CRBBDK2%2Fref%3Dsr_1_194_sspa%3Fdchild%3D1%26keywords%3DSneakers%26qid%3D1632468513%26sr%3D8-194-spons%26psc%3D1&qualifier=1632468513&id=7798684811302917&widgetName=sp_atf_next',
# ...

# %%
ratings=[]#empty list
for i in urls:
    driver.get(i)
    #time.sleep(1)
    try:
        rate_tags=.driver.find_elements_by_xpath("//span[@class='a-size-base a-nowrap']") #fetching rating tag using xpath
        ratings.append(rate_tags.text)
    except:
        ratings.append('-')
ratings
print(ratings)
# Out:
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-']

# %%
price_tags=[]    #empty list
for i in range(10):
    try:
        for j in driver.find_elements_by_xpath("//span[@class='a-price-whole']"):#fetching the price tag using xpath
            price_tags.append(j.text)
    except:
        price_tags.append("-")
print(price_tags)
# Out:
# ['4,199', '1,299', '4,973', '3,299', '1,288', '1,916', '601', '499', '1,155', '2,144', '279', '1,047', '1,399', '1,229', '1,380', '1,019', '799', '649', '1,814', '1,193', '6,269', '1,279', '5,669', '425', '999', '1,674', '639', '1,559', '839', '449', '389', '759', '499', '1,949', '835', '1,380', '1,144', '899', '809', '1,399', '2,498', '625', '2,366', '899', '2,597', '827', '749', '654', '399', '1,024', '649', '1,259', '1,432', '499', '789', '2,590', '5,249', '899', '3,795', '4,199', '1,299', '4,973', '3,299', '1,288', '1,916', '601', '499', '1,155', '2,144', '279', '1,047', '1,399', '1,229', '1,380', '1,019', '799', '649', '1,814', '1,193', '6,269', '1,279', '5,669', '425', '999', '1,674', '639', '1,559', '839', '449', '389', '759', '499', '1,949', '835', '1,380', '1,144', '899', '809', '1,399', '2,498', '625', '2,366', '899', '2,597', '827', '749', '654', '399', '1,024', '649', '1,259', '1,432', '499', '789', '2,590', '5,249', '899', '3,795', '4,199', '1,299', '4,973', '3,299', '1,
# ...

# %%
exg_tags=[]
for i in urls:
    driver.get(i)

    try:
        for j in driver.find_elements_by_xpath("//div[@data-icon-content='icon-farm-secondary-view-holder']"): #fetching exchange_tags using xpath
            exg_tags.append(j.text)
    except:
        exg_tags.append("-")
exg_tags[0:15]
# Out:
# ['30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange']

# %%
delivery_tags=[]#empty list
for i in urls:
    driver.get(i)

    try:
        for j in driver.find_elements_by_xpath('//div[@id="ddmDeliveryMessage"]//b'):#fetching delivery tag using xpath
            delivery_tags.append(j.text)
    except:
        delivery_tags.append("-")
print(delivery_tags)
# Out:
# ['Sunday, Sep 26', 'Tomorrow', 'Tuesday, Sep 28', 'Tuesday, Sep 28', 'Monday, Sep 27', 'Tuesday, Sep 28', 'Monday, Sep 27', 'Sunday, Sep 26', 'Wednesday, Sep 29', 'Sunday, Sep 26', 'Sep 30 - Oct 2', 'Saturday, Oct 9', 'Sep 30 - Oct 2', 'Sunday, Sep 26', 'Tomorrow', 'Sunday, Sep 26', 'Tomorrow', 'Sunday, Sep 26', 'Tomorrow', 'Sep 30 - Oct 2', 'Monday, Sep 27', 'Tomorrow', 'Sunday, Sep 26', 'Tomorrow']

# %%
rating_no=[]
for i in urls:
    driver.get(i)
    try:
        for j in driver.find_elements_by_id("acrCustomerReviewText"):#fetching no.of ratings tag using id
            rating_no.append(j.text)
    except:
        rating_no.append("-")
print(rating_no)
# Out:
# ['6 ratings', '6 ratings', '1 rating', '1 rating', '20 ratings', '20 ratings', '58 ratings', '58 ratings', '50 ratings', '50 ratings', '64 ratings', '64 ratings', '9 ratings', '9 ratings', '628 ratings', '628 ratings', '4 ratings', '4 ratings', '51 ratings', '51 ratings', '785 ratings', '785 ratings', '8 ratings', '8 ratings', '15 ratings', '15 ratings', '163 ratings', '163 ratings', '2 ratings', '2 ratings', '518 ratings', '518 ratings', '352 ratings', '352 ratings', '21 ratings', '21 ratings', '90 ratings', '90 ratings', '32 ratings', '32 ratings', '6 ratings', '6 ratings', '197 ratings', '197 ratings', '32 ratings', '32 ratings', '48 ratings', '48 ratings', '3,477 ratings', '3,477 ratings', '31 ratings', '31 ratings', '1,566 ratings', '1,566 ratings', '226 ratings', '226 ratings', '375 ratings', '375 ratings', '5 ratings', '5 ratings', '480 ratings', '480 ratings', '71 ratings', '71 ratings', '73 ratings', '73 ratings', '97 ratings', '97 ratings', '87 ratings', '87 ratings', '71 r
# ...

# %%
elems = driver.find_elements_by_xpath("//a[@href]")#fetching product urls using xpath
for elem in elems:
    print(elem.get_attribute("href"))
# Out:
# https://www.amazon.in/ref=nav_logo
# https://www.amazon.in/gp/customer-preferences/select-language/ref=topnav_lang?preferencesReturnUrl=%2FClarks-White-Leather-Sneakers-11-91261389087110%2Fdp%2FB07FR7S25T%2Fref%3Dsr_1_242_sspa%3Fdchild%3D1%26keywords%3DSneakers%26qid%3D1632468513%26sr%3D8-242-spons%26psc%3D1%26spLa%3DZW5jcnlwdGVkUXVhbGlmaWVyPUE1OFdPRUlZUkxTNk8mZW5jcnlwdGVkSWQ9QTAwNzkyMTkzMVNSNERVTlVRSkFVJmVuY3J5cHRlZEFkSWQ9QTA3ODM2MjBGWkU3TzNWSTYzRU8md2lkZ2V0TmFtZT1zcF9idGYmYWN0aW9uPWNsaWNrUmVkaXJlY3QmZG9Ob3RMb2dDbGljaz10cnVl
# ...

# %%
#creating the dataframe for the fetched data
df=pd.DataFrame({})
df['Brand']=brand_tags[0:15]
df['Product Name']=prod_tags[0:15]
df['Rating']=ratings[0:15]
df['No. of Ratings']=rating_no[0:15]
df['price']=price_tags[0:15]
df['Returns and Exchange']=exg_tags[0:15]
df['delivery']=delivery_tags[0:15]
df['Product URL']=elems[0:15]
df
# Out:
#                         Brand  \
# 0                    Skechers
# 1                     Walkway
# 2                    Neeman's
# 3                    Neeman's
# 4                    Red Tape
# 5                        Puma
# 6                    Converse
# 7   Bond Street by (Red Tape)
# 8                      Kraasa
# 9                 Allen Solly
# 10            Reebok Classics
# 11                    PARAGON
# 12                       Puma
# 13                Bacca Bucci
# 14                   Red Tape
#
#                                          Product Name Rating No. of Ratings  \
# 0                       Men's Benago-Extended Sneaker      -      6 ratings
# 1                             Men's 252-9880 Sneakers      -      6 ratings
# 2              Women's Wool Joggers Shoes (Coral Red)      -       1 rating
# 3            ReLive Knit Casual Slip On Shoes for Men      -       1 rating
# 4                                       Men's Sneaker      -     20 ratings
# ...

# %%
#saving the fetched data in csv file
df.to_csv('Amazon_products.csv', index=False, sep=',')

# %% [markdown]
# # Q3: Write a python program to access the search bar and search button on images.googlle.com and scrape 100 images each for keywords 'fruits','cars' and 'Machine Learning'.

# %%
driver=webdriver.Chrome(r"C:\Users\Win 10\Downloads\chromedriver_win32\chromedriver")

# %%
driver=webdriver.Chrome("chromedriver")

# %%
#passing the url
url='https://images.google.com/'
driver.get(url)

# %%
search_bar=driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")#fetching search_bar tag using xpath
search_button=driver.find_element_by_xpath("//button[@class='Tg7LZd']")#fetching search_button tag using xpath
print(search_bar)
print(search_button)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="58b847d026e36d13c8e443e1b39016e0", element="ad0b6d21-0c89-483a-b432-ae6a948736fa")>
# <selenium.webdriver.remote.webelement.WebElement (session="58b847d026e36d13c8e443e1b39016e0", element="9aeab914-7717-4de0-b716-96ff68005326")>

# %%
search_bar.send_keys('fruits')#sending input key for search_bar as "fruits"

# %%
search_button.click()#submitting the search icon

# %%
imgResults = driver.find_elements_by_xpath("//div[@class='bRMDJf islir']") #fetching image urls using xpath
totalResults=len(imgResults)
totalResults #printing length of total images in url
# Out:
# 400

# %%
img_urls = set() #empty set
for i in  range(0,100): #giving range as 100 for feetching only 100 images
    img=imgResults[i]
#using try and except method
    try:
        img.click()
        time.sleep(2) #passing the sleeptime
        actual_images = driver.find_elements_by_css_selector('img.n3VNCb') #fetching images by using css_selector 
        for actual_image in actual_images:
            if actual_image.get_attribute('src') and 'https' in actual_image.get_attribute('src'):
                img_urls.add(actual_image.get_attribute('src'))
    except ElementClickInterceptedException or ElementNotInteractableException as err:
        print(err)

# %%
#importing OS
import os

# %%
os.chdir('C:/Users/Seleniumimages')#giving the path of a folder in which scrapped images to be stored
baseDir=os.getcwd()

# %%
import requests
import io
from PIL import Image
for i, url in enumerate(img_urls):
    file_name = f"{i:100}.jpg"    
    #uisng try-except method
    try:
        image_content = requests.get(url).content

    except Exception as e:
        print(f"ERROR - COULD NOT DOWNLOAD {url} - {e}")

    try:
        image_file = io.BytesIO(image_content)
        image = Image.open(image_file).convert('RGB')
        
        file_path = os.path.join(baseDir, file_name)
        
        with open(file_path, 'wb') as f:
            image.save(f, "JPEG", quality=85)
        print(f"SAVED - {url} - AT: {file_path}")
    except Exception as e:
        print(f"ERROR - COULD NOT SAVE {url} - {e}")
# Out:
# SAVED - https://images.livemint.com/img/2021/08/03/600x338/dragon-fruit_1624713810023_1627993091830.jpg - AT: C:\Users\Seleniumimages\                                                                                                   0.jpg
# SAVED - https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTn0qoGnGU9OQ8X_gPKLh7gbvhqBqwB7zH90g&usqp=CAU - AT: C:\Users\Seleniumimages\                                                                                                   1.jpg
# SAVED - https://www.diagnosisdiet.com/assets/images/c/fruit-og-d176ef00.jpg - AT: C:\Users\Seleniumimages\                                                                                                   2.jpg
# SAVED - https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQlCy3oYbyuVFpu_1gPqRsxYmFnuhD8TyY33w&usqp=CAU - AT: C:\Users\Seleniumimages\                                                                                                   3.jpg
# ...

# %%
search_bar.send_keys('cars')#sending keys as cars for search_bar
search_button.click()#submitting the search_button

# %%
imgResults = driver.find_elements_by_xpath("//div[@class='bRMDJf islir']")#fetching car images tag using xpath
totalResults=len(imgResults)#assigning the length of cars to totalResults
totalResults#printing output
# Out:
# 300

# %%
img_urls = set()#empty set
for i in  range(0,100):
    img=imgResults[i]
    try:
        img.click()      #using try and except method 
        time.sleep(2)
        actual_images = driver.find_elements_by_css_selector('img.n3VNCb')
        for actual_image in actual_images:
            if actual_image.get_attribute('src') and 'https' in actual_image.get_attribute('src'):
                img_urls.add(actual_image.get_attribute('src'))
    except ElementClickInterceptedException or ElementNotInteractableException as err:
        print(err)

# %%
import os
os.chdir('C:/Users/Seleniumimages')#giving the path of a folder in which scrapped images to be stored
baseDir=os.getcwd()

# %%
import requests
import io
from PIL import Image
for i, url in enumerate(img_urls):
    file_name = f"{i:100}.jpg"    
    try:
        image_content = requests.get(url).content

    except Exception as e:
        print(f"ERROR - COULD NOT DOWNLOAD {url} - {e}")

    try:
        image_file = io.BytesIO(image_content)
        image = Image.open(image_file).convert('RGB')
                                                             #using try and except method
        file_path = os.path.join(baseDir, file_name)
        
        with open(file_path, 'wb') as f:
            image.save(f, "JPEG", quality=85)
        print(f"SAVED - {url} - AT: {file_path}")
    except Exception as e:
        print(f"ERROR - COULD NOT SAVE {url} - {e}")
# Out:
# SAVED - https://media.zigcdn.com/media/model/2021/May/seltos-3_270x180.jpg - AT: C:\Users\Seleniumimages\                                                                                                   0.jpg
# SAVED - https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS4M9KI_4aRw3oCydWnNUuQKfvC_yfStPzhoA&usqp=CAU - AT: C:\Users\Seleniumimages\                                                                                                   1.jpg
# SAVED - https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSClg8Jv0CIQXDk7hlr1b9X_T5zrK-YzQBA_w&usqp=CAU - AT: C:\Users\Seleniumimages\                                                                                                   2.jpg
# SAVED - https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTe95-bGY1zliejdM0FssE9jzcTpr_zMSZjiw&usqp=CAU - AT: C:\Users\Seleniumimages\                                                                                                   3.jpg
# ...

# %%
search_bar.send_keys('Machine Learning')#sending key as Machine Learning
search_button.click()#submitting search_button

# %%
imgResults = driver.find_elements_by_xpath("//div[@class='bRMDJf islir']")#fetching images tags using xpath
totalResults=len(imgResults)
totalResults  #printing the length
# Out:
# 382

# %%
img_urls = set()#empty set
for i in  range(0,100):
    img=imgResults[i]
    try:
        img.click()
        time.sleep(2)
        actual_images = driver.find_elements_by_css_selector('img.n3VNCb')
        for actual_image in actual_images:
            if actual_image.get_attribute('src') and 'https' in actual_image.get_attribute('src'):
                img_urls.add(actual_image.get_attribute('src'))
    except ElementClickInterceptedException or ElementNotInteractableException as err:
        print(err)

# %%
import os
os.chdir('C:/Users/Seleniumimages')
baseDir=os.getcwd()

# %%
import requests
import io
from PIL import Image
for i, url in enumerate(img_urls):
    file_name = f"{i:100}.jpg"    
    try:
        image_content = requests.get(url).content

    except Exception as e:
        print(f"ERROR - COULD NOT DOWNLOAD {url} - {e}")

    try:
        image_file = io.BytesIO(image_content)                    #using try and except method
        image = Image.open(image_file).convert('RGB')
        
        file_path = os.path.join(baseDir, file_name)
        
        with open(file_path, 'wb') as f:
            image.save(f, "JPEG", quality=85)
        print(f"SCRAPPED AND SAVED - {url} - AT: {file_path}")
    except Exception as e:
        print(f"ERROR - COULD NOT SAVE {url} - {e}")
# Out:
# SCRAPPED AND SAVED - https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQpOS6K8MU7vUTwsr3qJOaA65r88DKNoQ35HA&usqp=CAU - AT: C:\Users\Seleniumimages\                                                                                                   0.jpg
# SCRAPPED AND SAVED - https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQh4HzGIRo74WpbQfcr6SFZFkcsiykKzX5A-w&usqp=CAU - AT: C:\Users\Seleniumimages\                                                                                                   1.jpg
# SCRAPPED AND SAVED - https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRVTT3e6fT7u4ormLM5SnutHobjS_Z4CSDeFg&usqp=CAU - AT: C:\Users\Seleniumimages\                                                                                                   2.jpg
# ...

# %% [markdown]
# # Q4: Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Display Resolution”, “Processor”, “Processor Cores”, “Battery Capacity”, “Price”, “Product URL”. In case if any of the details is missing then replace it by "-". Save your results in a dataframe and CSV.

# %%
driver=webdriver.Chrome(r"C:\Users\Win 10\Downloads\chromedriver_win32\chromedriver")
driver=webdriver.Chrome("chromedriver")
url='https://www.flipkart.com/'   #passing url
driver.get(url)

# %%
search_field=driver.find_element_by_xpath('//input[@class="_3704LK"]') #fetching search_field tag using xpath
search_field.send_keys("galaxy note 20")        #giving input keys
search_button=driver.find_element_by_xpath('//button[@class="L0Z3Pu"]') #fetching search button tag using xpath
search_button.click()                           #submitting search button

# %%
#empty lists to store data
smartphone_name=[]
colour=[]
RAM=[]
storage_ROM=[]
primary_camera=[]
secondary_camera=[]
display_size=[]
display_resolution=[]
processor=[]
processor_cores=[]
battery_capacity=[]

# %%
for links in driver.find_elements_by_xpath("//a[@class='_1fQZEK']"):
    urls.append(links.get_attribute('href'))

# Iterating through the URL list and accessing each link to extract data    
for url in urls:
    driver.get(url)
    time.sleep(2)
    driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
    time.sleep(1)
    
    # Storing all the table rows
    model=driver.find_elements_by_xpath("//tr[@class='_1s_Smc row']")

    # Iterating through the Table rows to get required data
    for name in model:
        text1=name.find_element_by_xpath("td[1]").text # Storing text for first Table Data for each row to check 'if' condition
    
        # Extracting Model name
        if text1=='Model Name':
            smartphone_name.append(name.find_element_by_xpath("td[2]").text)

        # Extracting Phone Color
        if text1=='Color':
            colour.append(name.find_element_by_xpath("td[2]").text)

        # Extracting Display Size
        if text1=='Display Size':
            display_size.append(name.find_element_by_xpath("td[2]").text)

        # Extracting Display Resolution
        if text1=='Resolution':
             display_resolution.append(name.find_element_by_xpath("td[2]").text)

        # Extracting Processor        
        if text1=='Processor Type':
            processor.append(name.find_element_by_xpath("td[2]").text)

        # Extracting Cores in Processor
        if text1=='Processor Core':
            processor_cores.append(name.find_element_by_xpath("td[2]").text)

        # Extracting Internal Storage(ROM)
        if text1=='Internal Storage':
            storage_ROM.append(name.find_element_by_xpath("td[2]").text)

        # Extracting RAM Memory
        if text1=='RAM':
            RAM.append(name.find_element_by_xpath("td[2]").text)

        # Extracting Primary Camera Details
        if text1=='Primary Camera':
            primary_camera.append(name.find_element_by_xpath("td[2]").text)

        # Extracting Secondary Camera Details

        if text1=='Secondary Camera':
            secondary_camera.append(name.find_element_by_xpath("td[2]").text)

        # Extracting Battery Capacity
        if text1=='Battery Capacity':
            battery_capacity.append(name.find_element_by_xpath("td[2]").text)
print("Names:",smartphone_name)
print("Colour:",colour)
print("Dispaly Size:",display_size)
print("Display Resolution:",display_resolution)
print("Processor:",processor)
print("Processor_cores:",processor_cores)
print("Storage(ROM):",storage_ROM)
print("RAM:",RAM)
print("Primary Camera:",primary_camera)
print("Secondary camera:",secondary_camera)
print("Battery Capacity:",battery_capacity)
# Out:
# Names: ['C3', 'C20', 'C20', 'M3', 'C3', '9i', 'C3', 'C3', 'C11 2021', 'C11 2021', 'A53', 'A53', '9 Prime', '9 Power', 'A12', 'A12', '9i', 'A12', 'A12', 'A12', 'A12', 'M2 Reloaded', 'M3', '9 Power', 'Galaxy Note 20', 'Galaxy Note 20', 'Galaxy Note 20', 'Galaxy Note 20 Ultra 5G', 'Galaxy Note 20 Ultra 5G', 'Galaxy Note 5', 'Galaxy Note 5', 'Galaxy Note 5 (Dual Sim)', 'Galaxy Note 5 (Dual Sim)', 'Galaxy Note 5 (Dual Sim)', 'Galaxy Note 5', 'Galaxy Note Edge', 'Galaxy Note 5', 'Galaxy Note 5', 'Galaxy Note 5', 'Galaxy Note 5', 'Galaxy Note 4', 'Galaxy Note 4', 'Galaxy Note 5 Dual', 'Galaxy Note 4', 'Galaxy Note 4']
# ...

# %%
#fetching price
price=[] #empty list
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='_30jeq3 _1_WHN1']"):
        price.append(j.text)
print("Price:",price)
# Out:
# Price: ['₹77,999', '₹54,599', '₹59,999', '₹91,999', '₹91,999', '₹46,900', '₹56,999', '₹46,300', '₹46,300', '₹46,300', '₹30,495', '₹30,000', '₹29,990', '₹38,900', '₹29,990', '₹49,990', '₹51,000', '₹36,900', '₹39,899', '₹27,990', '₹49,990', '₹77,999', '₹54,599', '₹59,999', '₹91,999', '₹91,999', '₹46,900', '₹56,999', '₹46,300', '₹46,300', '₹46,300', '₹30,495', '₹30,000', '₹29,990', '₹38,900', '₹29,990', '₹49,990', '₹51,000', '₹36,900', '₹39,899', '₹27,990', '₹49,990', '₹77,999', '₹54,599', '₹59,999', '₹91,999', '₹91,999', '₹46,900', '₹56,999', '₹46,300', '₹46,300', '₹46,300', '₹30,495', '₹30,000', '₹29,990', '₹38,900', '₹29,990', '₹49,990', '₹51,000', '₹36,900', '₹39,899', '₹27,990', '₹49,990', '₹77,999', '₹54,599', '₹59,999', '₹91,999', '₹91,999', '₹46,900', '₹56,999', '₹46,300', '₹46,300', '₹46,300', '₹30,495', '₹30,000', '₹29,990', '₹38,900', '₹29,990', '₹49,990', '₹51,000', '₹36,900', '₹39,899', '₹27,990', '₹49,990', '₹77,999', '₹54,599', '₹59,999', '₹91,999', '₹91,999', '₹46,900', 
# ...

# %%
#fetching product urls
prod_urls = driver.find_elements_by_xpath("//a[@href]") #fetching product urls using xpath
for urls in prod_urls:
    print(urls.get_attribute("href"))
# Out:
# https://www.flipkart.com/
# https://www.flipkart.com/plus
# https://www.flipkart.com/search?q=galaxy+note+20+ultra&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_14_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_14_na_na_ps&as-pos=1&as-type=RECENT&suggestionId=galaxy+note+20+ultra%7CMobiles&requestId=8d642f3c-d823-4829-8f35-6fc172c3d9ce&as-searchtext=galaxy%20note%2020
# https://www.flipkart.com/search?q=galaxy+note+20&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_2_14_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_2_14_na_na_ps&as-pos=2&as-type=RECENT&suggestionId=galaxy+note+20%7CMobiles&requestId=8d642f3c-d823-4829-8f35-6fc172c3d9ce&as-searchtext=galaxy%20note%2020
# ...

# %%
#Creating a dataframe for fetched data
data=pd.DataFrame({})
data['Smartphone Name']=smartphone_name[0:20]
data['Colour']=colour[0:20]
data['RAM']=RAM[0:20]
data['Storage(ROM)']=storage_ROM[0:20]
data['Primary Camera']=primary_camera[0:20]
data['Secondary Camera']=secondary_camera[0:20]
data['Dispaly Size']=display_size[0:20]
data['Display Resolution']=display_resolution[0:20]
data['Processor']=processor[0:20]
data['Processor Cores']=processor_cores[0:20]
data['Battery Capacity']=battery_capacity[0:20]
data['Price']=price[0:20]
data['Product URL']=prod_urls[0:20]
data
# Out:
#    Smartphone Name           Colour   RAM Storage(ROM)  \
# 0               C3      Arctic Blue  4 GB        64 GB
# 1              C20        Cool Blue  2 GB        32 GB
# 2              C20        Cool Grey  2 GB        32 GB
# 3               M3        Cool Blue  4 GB        64 GB
# 4               C3      Matte Black  3 GB        32 GB
# 5               9i     Nature Green  4 GB        64 GB
# 6               C3       Lime Green  3 GB        32 GB
# 7               C3      Arctic Blue  3 GB        32 GB
# 8         C11 2021        Cool Blue  2 GB        32 GB
# 9         C11 2021        Cool Grey  2 GB        32 GB
# 10             A53       Mint Cream  4 GB        64 GB
# 11             A53  Moonlight Black  4 GB        64 GB
# 12         9 Prime       Space Blue  4 GB        64 GB
# 13         9 Power     Blazing Blue  4 GB        64 GB
# 14             A12   Flowing Silver  4 GB        64 GB
# 15             A12   Flowing Silver  3 GB        32 GB
# ...

# %%
data.to_csv('SmartPhone_details.csv', index=False, sep=',') #saving the fetched data in csv file
print("File saved")
# Out:
# File saved

# %% [markdown]
# # Q5: Write a python program to scrap geospatial coordinates(latitude,longitude) of a city searched on google maps.

# %%
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By                             
from selenium.webdriver.support import expected_conditions as EC          #importing required libraries
from selenium.webdriver.common.action_chains import ActionChains

driver=webdriver.Chrome(r"C:\Users\Win 10\Downloads\chromedriver_win32\chromedriver")
driver=webdriver.Chrome("chromedriver")
wait=WebDriverWait(driver,20)
driver.get("https://www.google.com/maps")
wait.until(EC.element_to_be_clickable((By.ID, "searchboxinput"))).send_keys("Bengaluru")  #fetching search_field by id and sending keys
wait.until(EC.element_to_be_clickable((By.ID, "searchbox-searchbutton"))).click() #submitting search_button
time.sleep(20)
ActionChains(driver).move_to_element(driver.find_element_by_xpath("//html/body")).context_click().perform()
print("Longitude,Latitude:",wait.until(EC.visibility_of_element_located((By.CSS_SELECTOR, "ul[role='menu']>li div div[class*='text']:nth-of-type(1)"))).text)
# Out:
# Longitude,Latitude: 12.95519, 77.35073

# %% [markdown]
# # Q6:Write a program to scrap details of all the funding deals for second quarter(i.e.July 20 - september 20) from trak.in

# %%
driver=webdriver.Chrome(r"C:\Users\Win 10\Downloads\chromedriver_win32\chromedriver")
driver=webdriver.Chrome("chromedriver")
url='https://trak.in/india-startup-funding-investment-2015/'   #passing url
driver.get(url)
time.sleep(1)
trak_tags=[]
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='dataTables_scroll']"): #fetching details tag using xpath
        trak_tags.append(j.text)
    time.sleep(2)
trak_tags
# Out:
# ["Sr. No. Date (dd/mm/yyyy) Startup Name Industry / Vertical Sub-Vertical City / Location Investors' Name Investment Type Amount (In USD)\n1 01/04/2021 BYJU’S Edu-tech Online tutoring Bengaluru Innoven Capital Series F 460,000,000\n2 05/04/2021 Meesho E-commerce Online reselling platform Bengaluru SoftBank Vision Fund 2 Series E 300,000,000\n3 14/04/2021 Swiggy Online Food Delivery Online Food Delivery Bengaluru Amansa Holdings, Carmignac, Falcon Edge Capital, Goldman Sachs, Think Investments Series J 343,000,000\n4 07/04/2021 Groww FinTech Investment platform Bengaluru MC Global Edtech, B Capital, Baron, others Series D 83,000,000\n5 14/04/2021 Beldara E-commerce Global B2B marketplace Mumbai Hindustan Media Ventures Venture 7,400,000",
# ...

# %% [markdown]
# # Q7:Write a python program to scrape all the available details of best gaming laptops from digit.in.

# %%
driver=webdriver.Chrome(r"C:\Users\Win 10\Downloads\chromedriver_win32\chromedriver")
driver=webdriver.Chrome("chromedriver")
url='https://www.digit.in/search/?keyword=gaming%20laptops'   #passing url
driver.get(url)
time.sleep(3)

# %%
details=[] #empty lists
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='searchProduct-desc']"):
        details.append(j.text) 
    time.sleep(5)
details
# Out:
# ['HP Envy 15-k006tx',
#  'Asus G750JX-CV069P',
#  "ASUS G53J - A 3D gamer's delight but we want more",
#  'Lenovo IdeaPad Y570',
#  'ASUS ROG Flow x13',
#  'ASUS ROG Cetra',
#  'HP Pavilion g6 - Multimedia and gaming on a budget',
#  'Truvison TX3271',
#  'ASUS Zephyrus G15 Ryzen 9 5900HS (2021)',
#  'Lenovo G50-30',
#  'HP Envy 15-k006tx',
#  'Asus G750JX-CV069P',
#  "ASUS G53J - A 3D gamer's delight but we want more",
#  'Lenovo IdeaPad Y570',
#  'ASUS ROG Flow x13',
#  'ASUS ROG Cetra',
#  'HP Pavilion g6 - Multimedia and gaming on a budget',
#  'Truvison TX3271',
#  'ASUS Zephyrus G15 Ryzen 9 5900HS (2021)',
#  'Lenovo G50-30',
#  'HP Envy 15-k006tx',
#  'Asus G750JX-CV069P',
#  "ASUS G53J - A 3D gamer's delight but we want more",
#  'Lenovo IdeaPad Y570',
#  'ASUS ROG Flow x13',
#  'ASUS ROG Cetra',
#  'HP Pavilion g6 - Multimedia and gaming on a budget',
#  'Truvison TX3271',
#  'ASUS Zephyrus G15 Ryzen 9 5900HS (2021)',
#  'Lenovo G50-30',
#  'HP Envy 15-k006tx',
# ...

# %%
available_details=[]
for i in range(100):
    for j in driver.find_elements_by_xpath("//div[class='product_details']"):
        available_details.append(j.text)
available_details
# Out:
# ['LAUNCHED\nMarket Status :\nLAUNCHED\nRelease Date :\n14 Oct, 2014\nOfficial Website :\nAsus\nKey Specifications\nOS\nNA\nDisplay\nNA\nProcessor\nNA\nAsus G750JX-CV069P Price in India: ₹ 149,999 (onwards)\nAvailable at Store\nSee All Prices',
#  'LAUNCHED\nMarket Status :\nLAUNCHED\nRelease Date :\n14 Oct, 2014\nOfficial Website :\nAsus\nKey Specifications\nOS\nNA\nDisplay\nNA\nProcessor\nNA\nAsus G750JX-CV069P Price in India: ₹ 149,999 (onwards)\nAvailable at Store\nSee All Prices',
#  'LAUNCHED\nMarket Status :\nLAUNCHED\nRelease Date :\n14 Oct, 2014\nOfficial Website :\nAsus\nKey Specifications\nOS\nNA\nDisplay\nNA\nProcessor\nNA\nAsus G750JX-CV069P Price in India: ₹ 149,999 (onwards)\nAvailable at Store\nSee All Prices',
#  'LAUNCHED\nMarket Status :\nLAUNCHED\nRelease Date :\n14 Oct, 2014\nOfficial Website :\nAsus\nKey Specifications\nOS\nNA\nDisplay\nNA\nProcessor\nNA\nAsus G750JX-CV069P Price in India: ₹ 149,999 (onwards)\nAvailable at Store\nSee All Prices',
# ...

# %% [markdown]
# # Q8:Write a program to scrape the details for all billionaries from www.forbes.com.Details to be scrapped:"Rank","Name","Net Worth","Age","Citizenship","Source","Industry".

# %%
from selenium.webdriver.support.ui import WebDriverWait
import re
driver=webdriver.Chrome(r"C:\Users\Win 10\Downloads\chromedriver_win32\chromedriver")
driver=webdriver.Chrome("chromedriver")
url='https://www.forbes.com/real-time-billionaires/#623cbcd03d78'   #passing url
driver.get(url)

# %%
billionaries_details=[]
for j in driver.find_elements_by_xpath("//tr[@class='base ng-scope']"):
        billionaries_details.append(j.text.replace("\n"," "))
billionaries_details
# Out:
# ['1 Elon Musk $199.6 B ▶ $4.6 B | 2.36% 50 Tesla, SpaceX United States',
#  '2 Jeff Bezos $198.7 B ▶ $487 M | 0.25% 57 Amazon United States',
#  '3 Bernard Arnault & family $181.9 B ▶ $3.2 B | -1.71% 72 LVMH France',
#  '4 Bill Gates $131.7 B ▶ $65 M | -0.05% 65 Microsoft United States',
#  '5 Mark Zuckerberg $126.2 B ▶ $2.5 B | 1.99% 37 Facebook United States',
#  '6 Larry Page $121.6 B ▶ $718 M | 0.59% 48 Google United States',
#  '7 Larry Ellison $118.1 B ▶ $873 M | 0.74% 77 software United States',
#  '8 Sergey Brin $117.2 B ▶ $686 M | 0.59% 48 Google United States',
#  '9 Warren Buffett $100.8 B ▶ $69 M | -0.07% 91 Berkshire Hathaway United States',
#  '10 Mukesh Ambani $96.1 B ▶ $259 M | -0.27% 64 diversified India',
#  '11 Steve Ballmer $96.0 B ▶ $56 M | -0.06% 65 Microsoft United States',
#  "12 Francoise Bettencourt Meyers & family $87.8 B ▶ $1.9 B | -2.16% 68 L'Oréal France",
#  '13 Amancio Ortega $84.6 B ▶ $830 M | -0.97% 85 Zara Spain',
# ...

# %% [markdown]
# # Q9:Write a program to extract atleast 500 comments, comment upvote and time when comment was posted from any Youtube video.

# %%
youtube_pages = "https://www.youtube.com/"   #passing url
driver=webdriver.Chrome(r"C:\Users\Win 10\Downloads\chromedriver_win32\chromedriver")
driver=webdriver.Chrome("chromedriver")
driver.get(youtube_pages)

# %%
search = driver.find_element_by_xpath('//input') #fetching search_field tag using xpath
search.send_keys("Kishore Kumar")    
driver.find_element_by_id('search-icon-legacy').click()   #proceeding to search

# %%
comments=[]
for i in range(10):
    for j in driver.find_elements_by_id("content-text"):
        comments.append(j.text)
comments
# Out:
# ['Such a lezender singer india will ever and never witness',
#  'I am 16 I listing song love you Kishore g',
#  'NOBODY CAN MATCH KISHORE KUMAR IN DUET EXCEPT LATA MANGESHKAR',
#  "Kishor da you're legend ️ wish I could see u live ",
#  'Sir thanks  for this songs sir ye suun ne ye bad bahot sukun laga ',
#  'Every time every moments your songs yours voice great kishore da ',
#  'सर्व गीत अमर आहेत',
#  'Extremely happy to listen  my  fav in one frame',
#  'Whenever i get time i used to listen  these songs and i really feel \n\n  fresh each and every song of kishor sir  heart touching ️️️',
#  'Great mood refresher always KISHOREDA , the LEGEND ',
#  "These masterpieces ️\nNow a days most of the songs don't portray any meaning \nI prefer these songs, electronic music over today's Bollywood songs..\nKishore Da️",
#  'Miss u kishore da....',
#  'I love songs ',
#  'mistske wolf signs its self has fear',
# ...

# %%
upvotes=[]
for i in range(10):
    try:
        for j in driver.find_elements_by_xpath("//span[@id='vote-count-middle']"):
            upvotes.append(j.text)
    except:
        upvotes.append("-")
upvotes
# Out:
# ['79',
#  '3',
#  '',
#  '27',
#  '45',
#  '76',
#  '8',
#  '9',
#  '27',
#  '6',
#  '30',
#  '1',
#  '1',
#  '',
#  '6',
#  '125',
#  '126',
#  '10',
#  '',
#  '',
#  '80',
#  '5',
#  '3',
#  '7',
#  '25',
#  '122',
#  '6',
#  '1',
#  '3',
#  '3',
#  '90',
#  '10',
#  '4',
#  '',
#  '1',
#  '21',
#  '',
#  '24',
#  '10',
#  '37',
#  '116',
#  '',
#  '3',
#  '10',
#  '7',
#  '32',
#  '7',
#  '',
#  '5',
#  '15',
#  '23',
#  '5',
#  '',
#  '5',
#  '',
#  '139',
#  '10',
#  '4',
#  '',
#  '',
#  '173',
#  '3',
#  '2',
#  '',
#  '',
#  '32',
#  '',
#  '1',
#  '',
#  '15',
#  '101',
#  '',
#  '7',
#  '2',
#  '4',
#  '17',
#  '6',
#  '9',
#  '',
#  '',
#  '179',
#  '',
#  '',
#  '1',
#  '8',
#  '20',
#  '11',
#  '1',
#  '',
#  '',
#  '84',
#  '5',
#  '4',
#  '3',
#  '11',
#  '43',
#  '3',
#  '8',
#  '1',
#  '',
#  '200',
#  '1',
#  '4',
#  '',
#  '13',
#  '79',
#  '',
#  '4',
#  '49',
#  '',
#  '46',
#  '16',
#  '',
#  '',
#  '',
#  '23',
#  '10',
#  '',
#  '',
#  '3',
#  '144',
#  '4',
# ...

# %%
time=[]
for i in range(10):
    for j in driver.find_elements_by_xpath("//yt-formatted-string[@class='published-time-text above-comment style-scope ytd-comment-renderer']"):
        time.append(j.text)
time
# Out:
# ['4 months ago',
#  '1 week ago',
#  '6 hours ago',
#  '3 weeks ago',
#  '2 months ago',
#  '9 months ago',
#  '5 days ago',
#  '1 month ago',
#  '1 month ago',
#  '2 months ago',
#  '5 months ago',
#  '1 month ago',
#  '5 days ago',
#  '16 hours ago',
#  '2 months ago',
#  '9 months ago',
#  '1 month ago',
#  '1 month ago',
#  '5 days ago',
#  '1 hour ago',
#  '2 months ago',
#  '3 weeks ago',
#  '1 month ago',
#  '2 months ago',
#  '1 month ago',
#  '11 months ago',
#  '3 weeks ago',
#  '6 days ago',
#  '1 month ago',
#  '1 month ago',
#  '8 months ago',
#  '1 month ago',
#  '6 days ago',
#  '5 days ago',
#  '2 weeks ago',
#  '6 months ago',
#  '2 months ago',
#  '1 week ago',
#  '1 month ago',
#  '1 month ago',
#  '10 months ago',
#  '2 days ago',
#  '1 month ago',
#  '1 month ago',
#  '1 month ago',
#  '9 months ago',
#  '2 weeks ago',
#  '1 week ago',
#  '1 month ago',
#  '1 month ago',
#  '7 months ago',
#  '1 week ago',
#  '4 weeks ago',
#  '1 month ago',
#  '1 month ago',
# ...

# %% [markdown]
# # Q10:Write a python program to scrape for all available hostels from https://www.hostelworld.com/in "London" location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description.

# %%
driver=webdriver.Chrome(r"C:\Users\Win 10\Downloads\chromedriver_win32\chromedriver")
driver=webdriver.Chrome("chromedriver")
url='https://www.hostelworld.com/'             #passing url
driver.get(url)              
search = driver.find_element_by_xpath("//input")
search.send_keys("London")
submit=driver.find_element_by_xpath("//button[@id='search-button']")
submit.click()

# %%
hostel_name=[]
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='title-row']//h2"): #fetching hostel_name tag using xpath
        hostel_name.append(j.text)
hostel_name
# Out:
# ["Wombat's The City Hostel London",
#  'Selina Camden',
#  'London Backpackers',
#  'London Waterloo Hostel',
#  "St Christopher's Inn - London Bridge",
#  'Barmy Badger Backpackers',
#  "Wombat's The City Hostel London",
#  'Prime Backpackers Angel',
#  "St Christopher's Village",
#  'PubLove @ The Steam Engine, Waterloo',
#  'Smart Camden Inn Hostel',
#  'PubLove @ The Crown, Battersea',
#  'Safestay London Elephant & Castle',
#  'Urbany Hostel London',
#  'PubLove @ The Green Man, Paddington',
#  'Mornington Camden',
#  'PubLove @ The Rose & Crown',
#  'New Cross Inn Hostel',
#  'Strand Continental',
#  "St Christopher's Oasis-Female Only",
#  'Astor Museum Inn',
#  'Astor Kensington',
#  'Mapesbury Hostel',
#  'Astor Hyde Park',
#  'Phoenix Hostel',
#  '247london Hostel and Private Rooms',
#  'Burlington Residence',
#  'SoHostel',
#  'Clink261',
#  'Generator London',
#  'PubLove @ The White Ferry, Victoria',
#  'Smart Russell Square Hostel',
#  'Keystone House Kings Cross',
# ...

# %%
distance=[]
for i in range(10):
    for j in driver.find_elements_by_xpath("//span[@class='description']"):
        distance.append(j.text)
distance
# Out:
# ['Hostel - 0.7km from city centre',
#  'Hostel - 1.8km from city centre',
#  'Hostel - 5.5km from city centre',
#  'Hostel - 3.6km from city centre',
#  'Hostel - 3.6km from city centre',
#  'Hostel - 1.8km from city centre',
#  'Hostel - 0.5km from city centre',
#  'Hostel - 4.4km from city centre',
#  'Hostel - 4.7km from city centre',
#  'Hostel - 1.7km from city centre',
#  'Hostel - 5.4km from city centre',
#  'Hostel - 4.3km from city centre',
#  'Hostel - 4.1km from city centre',
#  'Hostel - 1.6km from city centre',
#  'Hostel - 6.1km from city centre',
#  'Hostel - 1.3km from city centre',
#  'Hostel - 1.8km from city centre',
#  'Hostel - 2.2km from city centre',
#  'Hostel - 4.9km from city centre',
#  'Hostel - 8.2km from city centre',
#  'Hostel - 4.3km from city centre',
#  'Hostel - 4.2km from city centre',
#  'Hostel - 8.2km from city centre',
#  'Hostel - 7.1km from city centre',
#  'Hostel - 2km from city centre',
#  'Hostel - 3.2km from city centre',
# ...

# %%
ratings=[]
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='score orange big']"):
        ratings.append(j.text)
ratings
# Out:
# ['7.2',
#  '7.0',
#  '9.7',
#  '8.8',
#  '10',
#  '8.7',
#  '8.5',
#  '7.6',
#  '6.8',
#  '8.0',
#  '9.8',
#  '6.2',
#  '10',
#  '7.9',
#  '6.9',
#  '7.8',
#  '8.1',
#  '9.4',
#  '7.7',
#  '6.3',
#  '9.1',
#  '7.9',
#  '6.6',
#  '9.3',
#  '8.4',
#  '7.6',
#  '7.6',
#  '9.0',
#  '7.1',
#  '8.1',
#  '7.2',
#  '7.0',
#  '9.7',
#  '8.8',
#  '10',
#  '8.7',
#  '8.5',
#  '7.6',
#  '6.8',
#  '8.0',
#  '9.8',
#  '6.2',
#  '10',
#  '7.9',
#  '6.9',
#  '7.8',
#  '8.1',
#  '9.4',
#  '7.7',
#  '6.3',
#  '9.1',
#  '7.9',
#  '6.6',
#  '9.3',
#  '8.4',
#  '7.6',
#  '7.6',
#  '9.0',
#  '7.1',
#  '8.1',
#  '7.2',
#  '7.0',
#  '9.7',
#  '8.8',
#  '10',
#  '8.7',
#  '8.5',
#  '7.6',
#  '6.8',
#  '8.0',
#  '9.8',
#  '6.2',
#  '10',
#  '7.9',
#  '6.9',
#  '7.8',
#  '8.1',
#  '9.4',
#  '7.7',
#  '6.3',
#  '9.1',
#  '7.9',
#  '6.6',
#  '9.3',
#  '8.4',
#  '7.6',
#  '7.6',
#  '9.0',
#  '7.1',
#  '8.1',
#  '7.2',
#  '7.0',
#  '9.7',
#  '8.8',
#  '10',
#  '8.7',
#  '8.5',
#  '7.6',
#  '6.8',
#  '8.0',
# ...

# %%
total_reviews=[]
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='reviews']"):
        total_reviews.append(j.text) 
total_reviews
# Out:
# ['2419 Total Reviews',
#  '3237 Total Reviews',
#  '1659 Total Reviews',
#  '13191 Total Reviews',
#  '514 Total Reviews',
#  '10853 Total Reviews',
#  '194 Total Reviews',
#  '2687 Total Reviews',
#  '214 Total Reviews',
#  '3958 Total Reviews',
#  '124 Total Reviews',
#  '394 Total Reviews',
#  '41 Total Reviews',
#  '101 Total Reviews',
#  '1015 Total Reviews',
#  '781 Total Reviews',
#  '598 Total Reviews',
#  '8728 Total Reviews',
#  '6329 Total Reviews',
#  '357 Total Reviews',
#  '11338 Total Reviews',
#  '3434 Total Reviews',
#  '443 Total Reviews',
#  '30 Total Reviews',
#  '3984 Total Reviews',
#  '3178 Total Reviews',
#  '6745 Total Reviews',
#  '143 Total Reviews',
#  '9511 Total Reviews',
#  '8113 Total Reviews',
#  '2419 Total Reviews',
#  '3237 Total Reviews',
#  '1659 Total Reviews',
#  '13191 Total Reviews',
#  '514 Total Reviews',
#  '10853 Total Reviews',
#  '194 Total Reviews',
#  '2687 Total Reviews',
#  '214 Total Reviews',
#  '3958 Total Reviews',
# ...

# %%
privatesfromprice=[]
Dormsfromprice=[]
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='price title-5']"):
         for k in driver.find_elements_by_xpath("//div[@class='price title-5']"):
                privatesfromprice.append(j.text) 
                Dormsfromprice.append(k.text)
print(privatesfromprice)
print(Dormsfromprice)
# Out:
# ['Rs5732',
#  'Rs1486',
#  'Rs5459',
#  'Rs1254',
#  'Rs6268',
#  'Rs2123',
#  'Rs8657',
#  'Rs1808',
#  'Rs8786',
#  'Rs2392',
#  'Rs7683',
#  'Rs1254',
#  'Rs19410',
#  'Rs1584',
#  'Rs1292',
#  'Rs1584',
#  'Rs6369',
#  'Rs1820',
#  'Rs1880',
#  'Rs10514',
#  'Rs1550',
#  'Rs3169',
#  'Rs1651',
#  'Rs3918',
#  'Rs1297',
#  'Rs5914',
#  'Rs2275',
#  'Rs5526',
#  'Rs1506',
#  'Rs1617',
#  'Rs1415',
#  'Rs4549',
#  'Rs1516',
#  'Rs1175',
#  'Rs5156',
#  'Rs2062',
#  'Rs2022',
#  'Rs5726',
#  'Rs1471',
#  'Rs8934',
#  'Rs2430',
#  'Rs1617',
#  'Rs5908',
#  'Rs1259',
#  'Rs5186',
#  'Rs5732',
#  'Rs1486',
#  'Rs5459',
#  'Rs1254',
#  'Rs6268',
#  'Rs2123',
#  'Rs8657',
#  'Rs1808',
#  'Rs8786',
#  'Rs2392',
#  'Rs7683',
#  'Rs1254',
#  'Rs19410',
#  'Rs1584',
#  'Rs1292',
#  'Rs1584',
#  'Rs6369',
#  'Rs1820',
#  'Rs1880',
#  'Rs10514',
#  'Rs1550',
#  'Rs3169',
#  'Rs1651',
#  'Rs3918',
#  'Rs1297',
#  'Rs5914',
#  'Rs2275',
#  'Rs5526',
#  'Rs1506',
#  'Rs1617',
#  'Rs1415',
# ...

# %%
urls=[]
for i in driver.find_elements_by_xpath("//h2[@class='title title-6']//a"):
    urls.append(i.get_attribute("href"))
urls
# Out:
# ['https://www.hostelworld.com/pwa/hosteldetails.php/London-Waterloo-Hostel/London/39493?from=2021-09-26&to=2021-09-29&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Inn-London-Bridge/London/503?from=2021-09-26&to=2021-09-29&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Barmy-Badger-Backpackers/London/64746?from=2021-09-26&to=2021-09-29&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Wombat-s-The-City-Hostel-London/London/88047?from=2021-09-26&to=2021-09-29&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Prime-Backpackers-Angel/London/93902?from=2021-09-26&to=2021-09-29&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Village/London/502?from=2021-09-26&to=2021-09-29&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/PubLove-The-Steam-Engine-Waterloo/London/29389?from=2021-09-26&to=2021-09-29&guests=2',
# ...

# %%
overall_review=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='keyword']//span"):
        overall_review.append(j.text)

# %%
overall_review
# Out:
# ['Fabulous',
#  'Superb',
#  'Fabulous',
#  'Very Good',
#  'Very Good',
#  'Superb',
#  'Fabulous',
#  'Superb',
#  'Fabulous',
#  'Fabulous',
#  'Very Good',
#  'Good',
#  'Fabulous',
#  'Superb',
#  'Good',
#  'Superb',
#  'Very Good',
#  'Good',
#  'Very Good',
#  'Fabulous',
#  'Superb',
#  'Very Good',
#  'Good',
#  'Superb',
#  'Very Good',
#  'Good',
#  'Superb',
#  'Fabulous',
#  'Very Good',
#  'Very Good',
#  'Superb',
#  'Very Good',
#  'Fabulous',
#  'Fabulous',
#  'Superb',
#  'Fabulous',
#  'Very Good',
#  'Very Good',
#  'Superb',
#  'Fabulous',
#  'Superb',
#  'Fabulous',
#  'Fabulous',
#  'Very Good',
#  'Good',
#  'Fabulous',
#  'Superb',
#  'Good',
#  'Superb',
#  'Very Good',
#  'Good',
#  'Very Good',
#  'Fabulous',
#  'Superb',
#  'Very Good',
#  'Good',
#  'Superb',
#  'Very Good',
#  'Good',
#  'Superb',
#  'Fabulous',
#  'Very Good',
#  'Very Good',
#  'Superb',
#  'Very Good',
#  'Fabulous',
#  'Fabulous',
#  'Superb',
#  'Fabulous',
#  'Very Good',
# ...

# %%
facilities=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span[@class='rating body-2']"):
        facilities.append(j.text)

# %%
facilities
# Out:
# ['Perfect Location',
#  'Superb Staff',
#  'Awesome Cleanliness',
#  'Perfect Location',
#  'Superb Staff',
#  'Awesome Cleanliness',
#  'Perfect Location',
#  'Superb Staff',
#  'Awesome Cleanliness',
#  'Perfect Location',
#  'Superb Staff',
#  'Awesome Cleanliness',
#  'Perfect Location',
#  'Superb Staff',
#  'Awesome Cleanliness',
#  'Perfect Location',
#  'Superb Staff',
#  'Awesome Cleanliness',
#  'Perfect Location',
#  'Superb Staff',
#  'Awesome Cleanliness',
#  'Perfect Location',
#  'Superb Staff',
#  'Awesome Cleanliness',
#  'Perfect Location',
#  'Superb Staff',
#  'Awesome Cleanliness',
#  'Perfect Location',
#  'Superb Staff',
#  'Awesome Cleanliness']

# %%
job_desc=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//h4[@class='title-4']"):
        job_desc.append(j.text)

# %%
job_desc
# Out:
# ['Property Description',
#  'Check Availability',
#  'My Selection',
#  'Reviews & Ratings',
#  'Facilities',
#  'Property Description',
#  'Check Availability',
#  'My Selection',
#  'Reviews & Ratings',
#  'Facilities',
#  'Property Description',
#  'Check Availability',
#  'My Selection',
#  'Reviews & Ratings',
#  'Facilities',
#  'Property Description',
#  'Check Availability',
#  'My Selection',
#  'Reviews & Ratings',
#  'Facilities',
#  'Property Description',
#  'Check Availability',
#  'My Selection',
#  'Reviews & Ratings',
#  'Facilities',
#  'Property Description',
#  'Check Availability',
#  'My Selection',
#  'Reviews & Ratings',
#  'Facilities',
#  'Property Description',
#  'Check Availability',
#  'My Selection',
#  'Reviews & Ratings',
#  'Facilities',
#  'Property Description',
#  'Check Availability',
#  'My Selection',
#  'Reviews & Ratings',
#  'Facilities',
#  'Property Description',
#  'Check Availability',
#  'My Selection',
#  'Reviews & Ratings',
# ...
